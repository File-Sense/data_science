import requests
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO
import shutil
from google.colab import drive

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
dataset = pd.read_csv("Train_GCC-training.tsv", sep="\t", header=None)
dataset = dataset.rename(columns={0: "caption", 1: "image_url"})
dataset = Dataset.from_pandas(dataset)
dataset = dataset.filter(lambda example, idx: idx < 20000, with_indices=True)
dataset
# Out:
# Filter:   0%|          | 0/3318333 [00:00<?, ? examples/s]
# Dataset({
#     features: ['caption', 'image_url'],
#     num_rows: 20000
# })

# %%
def download_and_process_images(instance):
    session = requests.Session()
    try:
        image_url = instance["image_url"]
        response = session.get(image_url, timeout=1)
        if response.status_code == 200:
            image = Image.open(BytesIO(response.content))
            instance["image_data"] = image
            instance["drop_this_row"] = "no"
        else:
            instance["image_data"] = Image.fromarray(np.zeros((8,8,3),dtype=np.uint8))
            instance["drop_this_row"] = "yes"

    except requests.exceptions.Timeout:
        instance["image_data"] = Image.fromarray(np.zeros((8,8,3),dtype=np.uint8))
        instance["drop_this_row"] = "yes"

    except Exception as e:
        instance["image_data"] = Image.fromarray(np.zeros((8,8,3),dtype=np.uint8))
        instance["drop_this_row"] = "yes"
    session.close()
    return instance

# %%
dataset = dataset.map(download_and_process_images, batched=False)
# Out:
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]

# %%
dataset = dataset.filter(lambda instance: instance["drop_this_row"] == "no", with_indices=False)
dataset = dataset.remove_columns(["drop_this_row","image_url"])
dataset
# Out:
# Filter:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['caption', 'image_data'],
#     num_rows: 14154
# })

# %%
try:
    dataset.save_to_disk(f"{HOME}/Google_Conceptual_Caption_Dataset_Images_Captions")
except:
    print("Error in saving dataset locally")
# Out:
# Saving the dataset (0/2 shards):   0%|          | 0/14154 [00:00<?, ? examples/s]

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp {HOME}/Google_Conceptual_Caption_Dataset_Images_Captions /content/gdrive/My\ Drive/Google_Conceptual_Caption_Dataset_Images_Captions
# Out:
# cp: -r not specified; omitting directory '/content/Google_Conceptual_Caption_Dataset_Images_Captions'

# %%
dataset = load_from_disk(f"{HOME}/Google_Conceptual_Caption_Dataset_Images_Captions")
dataset
# Out:
# Dataset({
#     features: ['caption', 'image_data'],
#     num_rows: 14154
# })

# %%
for index in range(10,20):
    image_array = dataset[index]["image_data"]
    caption = dataset[index]["caption"]
    plt.imshow(image_array)
    plt.axis('off')
    print("\n\n\n Caption: ", caption )
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# ...

# %%
dataset.push_to_hub("pasindu/google_conceptual_captions_20000")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/48 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/pasindu/google_conceptual_captions_20000/commit/179295a3ec3007db90db1ab40149fc22b88684bc', commit_message='Upload dataset', commit_description='', oid='179295a3ec3007db90db1ab40149fc22b88684bc', pr_url=None, pr_revision=None, pr_num=None)
